# %%
# %pip install pybaseball
# Out:
# ...
#
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 459.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------------------- ------------------- 81.9/165.9 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.0 MB/s eta 0:00:00
# ...
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# ...
#    ---------------------------------------- 0.0/426.1 kB ? eta -:--:--
#    -------------------- ------------------ 225.3/426.1 kB 13.4 MB/s eta 0:00:01
# ...

# %%
from pybaseball import standings
data = standings(2024)
print(data)
# Out:
# [                  Tm   W   L  W-L%    GB  E#
# 1   New York Yankees  84  62  .575    --  --
# 2  Baltimore Orioles  83  64  .565   1.5  15
# 3     Boston Red Sox  74  72  .507  10.0   7
# 4     Tampa Bay Rays  71  75  .486  13.0   4
# 5  Toronto Blue Jays  69  78  .469  15.5   1,                     Tm   W    L  W-L%    GB  E#
# 1  Cleveland Guardians  84   62  .575    --  --
# 2   Kansas City Royals  80   67  .544   4.5  12
# 3      Minnesota Twins  78   68  .534   6.0  11
# 4       Detroit Tigers  75   71  .514   9.0   8
# 5    Chicago White Sox  33  114  .224  51.5   ☠,                    Tm   W   L  W-L%    GB  E#
# 1      Houston Astros  77  68  .531    --  --
# 2    Seattle Mariners  74  72  .507   3.5  14
# 3       Texas Rangers  70  76  .479   7.5  10
# 4   Oakland Athletics  64  82  .438  13.5   4
# 5  Los Angeles Angels  60  86  .411  17.5   ☠,                       Tm   W   L  W-L%    GB  E#
# 1  Philadelphia Phillies  88  58  .603    --  --
# ...
